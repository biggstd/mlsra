# %% [markdown]
# # Overivew of FPKM files

# %%
data = {'mouse_brain': '../data/nmeth.1226-S3.txt',
        'mouse_liver': '../data/nmeth.1226-S4.txt',
        'mouse_muscle': '../data/nmeth.1226-S5.txt'}

# %%
# Basic data science package imports.
import pandas as pd
import numpy as np

# %%
# Tensorflow imports.
import tensorflow as tf

# %%
# Visualization imports.
import bokeh
import bokeh.io
import bokeh.plotting

# Enable Bokeh notebook output.
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5d35cdb1-cb30-47e5-923e-29ca9aba2525">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ---
#
# ## Explore the data with Pandas

# %%
mouse_brain_df = pd.read_table(data['mouse_brain'])
mouse_liver_df = pd.read_table(data['mouse_liver'])
mouse_muscle_df = pd.read_table(data['mouse_muscle'])

# %%
print([len(x) for x in [mouse_brain_df, mouse_liver_df, mouse_muscle_df]])
# Out:
# [33598, 33598, 33598]

# %%
mouse_brain_df.describe(include='all')
# Out:
#           gid         RNAkb   gene     firstRPKM  expandedRPKM     finalRPKM  \
# count   33598  33598.000000  33598  33114.000000  33598.000000  33598.000000
# unique  33595           NaN  33595           NaN           NaN           NaN
# top     15510           NaN  Hspd1           NaN           NaN           NaN
# freq        2           NaN      2           NaN           NaN           NaN
# mean      NaN      3.761816    NaN     10.456045     10.031102     11.214082
# std       NaN     11.342678    NaN     50.824955     50.440814     81.403633
# min       NaN      0.100000    NaN      0.000000      0.000000      0.000000
# 25%       NaN      0.939000    NaN      0.000000      0.000000      0.020000
# 50%       NaN      1.937000    NaN      0.290000      0.310000      0.600000
# 75%       NaN      3.623000    NaN      5.227500      5.130000      5.760000
# max       NaN    641.200000    NaN   2941.550000   2876.570000  10365.250000
#
#         fractionMulti
# ...

# %%
mouse_brain_df.head()
# Out:
#          gid   RNAkb                gene  firstRPKM  expandedRPKM  finalRPKM  \
# 0  100008564  17.422       RP23-273B19.1       0.05          0.05       0.27
# 1  100009600   1.010                Glp1       0.46          0.52       0.44
# 2  100009609   2.481  ENSMUSG00000070600       0.01          0.01       0.01
# 3  100009698   1.497        LOC100009698       1.09          1.03       1.27
# 4     100012   1.832                Oog3       0.00          0.00       0.00
#
#    fractionMulti
# 0           0.84
# 1           0.00
# 2           0.00
# 3           0.32
# 4           0.00

# %% [markdown]
# ### Discussion of Columns
#
# + **gid** Gene universal identification number.
# + **RNAkb** kilo bases of RNA.
# + **gene** Text name of the gene.
# + **firstRPKM** ...
# + **expandedRPKM** ...
# + **finalRPKM** ...
# + **fractionMulti** ...
